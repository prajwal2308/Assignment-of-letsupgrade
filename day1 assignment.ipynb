# %%
int=5;

# %%
type(5)
# Out:
# int

# %%
print("hello world")
# Out:
# hello world

# %%
type(True)
# Out:
# bool

# %%
type(0.35)
# Out:
# float

# %%
type([1,2,3,4])
# Out:
# list

# %%
print(min(1,4,6,3))
# Out:
# 1

# %%
print(max(1,4,7,9,5))
# Out:
# 9

# %%
lst=['a' ,'b', 4,6]

# %%
len(lst)
# Out:
# 4

# %%
lst[:]
# Out:
# ['a', 'b', 4, 6]

# %%
lst.append(1)

# %%
lst[:]
# Out:
# ['a', 'b', 4, 6, 1]

# %%
max=(1,2,3)

# %%
max[:]
# Out:
# (1, 2, 3)

# %%
new={1,2,3,4,6}

# %%
print(new)
# Out:
# {1, 2, 3, 4, 6}
