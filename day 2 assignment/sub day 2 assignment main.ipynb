# %%
import numpy as np

# %%
lst = [1,2,3,4,5]
lst1 = [2,3,4,5,6]
lst2 = [4,5,6,7,8]

arr1 = np.array([lst, lst1, lst2])
arr1
# Out:
# array([[1, 2, 3, 4, 5],
#        [2, 3, 4, 5, 6],
#        [4, 5, 6, 7, 8]])

# %%
arr1[1:3,1:3]
# Out:
# array([[3, 4],
#        [5, 6]])
